# %%
import numpy as np

# %%
my_arr = np.arange(1_000_000)

# %%
my_list = list(range(1_000_000))

# %%
# %timeit my_arr2 = my_arr * 2
# Out:
# The slowest run took 4.84 times longer than the fastest. This could mean that an intermediate result is being cached.
# 26.7 ms ± 16.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit my_list2 = [x * 2 for x in my_list]
# Out:
# 555 ms ± 120 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
data1 = [6, 7.5, 8, 0, 1]
array1 = np.array(data1)

# %%
array1
# Out:
# array([6. , 7.5, 8. , 0. , 1. ])

# %%
arr = np.array([[0, 1, 0], [1, 2, -2], [6, 3, 2]])

# %%
arr2 = np.array([[0, 1, 0], [1, 2, -2], [6, 3, 2]])

# %%
np.dot(arr, arr)
# Out:
# array([[  1,   2,  -2],
#        [-10,  -1,  -8],
#        [ 15,  18,  -2]])

# %%
np.cos(3.142/3)
# Out:
# 0.4998824046113711

# %%
points = np.arange(-5, 5, 0.01) # 100 equally spaced points
xs, ys = np.meshgrid(points, points)

# %%
z = np.sqrt(xs ** 2 + ys ** 2)

# %%
import matplotlib.pyplot as plt
plt.imshow(z, cmap=plt.cm.gray, extent=[-5, 5, -5, 5])
plt.title("Image plot of $\sqrt{x^2 + y^2}$ for a grid of values")
# Out:
# Text(0.5, 1.0, 'Image plot of $\\sqrt{x^2 + y^2}$ for a grid of values')

# %%
arr.cumsum(axis = 0)  # cumulative sum across rows
arr. cumsum(axis = 1) # cumulative sum across columns
# Out:
# array([[ 0,  1,  1],
#        [ 1,  3,  1],
#        [ 6,  9, 11]], dtype=int32)

# %%
np.linalg.inv(arr)
# Out:
# array([[-7.14285714e-01,  1.42857143e-01,  1.42857143e-01],
#        [ 1.00000000e+00,  7.40148683e-17, -1.85037171e-17],
#        [ 6.42857143e-01, -4.28571429e-01,  7.14285714e-02]])

# %%
mat_a = np.array([[1,2,3],[2,3,4],[1,5,7]])
np.linalg.eig(mat_a)
# Out:
# (array([10.64178358+0.j       ,  0.17910821+0.3947894j,
#          0.17910821-0.3947894j]),
#  array([[ 0.35020626+0.j        , -0.04743341-0.30524686j,
#          -0.04743341+0.30524686j],
#         [ 0.50468916+0.j        , -0.76334996+0.j        ,
#          -0.76334996-0.j        ],
#         [ 0.78907821+0.j        ,  0.56204861+0.07728281j,
#           0.56204861-0.07728281j]]))
